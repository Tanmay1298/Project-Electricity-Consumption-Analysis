# %%
import pandas as pd

# %%
dataset = pd.read_csv('model_2.csv')

# %%
dataset
# Out:
#      input  billed
# 0     7631    5209
# 1    12634    7085
# 2    12380    9059
# 3     8367    5571
# 4     5196    3807
# 5     3283    2078
# 6     6942    4598
# 7      386     265
# 8    33921   22991
# 9      735     347
# 10    7571    6199
# 11     666     475
# 12    1669    1058
# 13     480     339
# 14     751     549
# 15    1250     813
# 16   12455   10902
# 17    7024    5980
# 18    8612    7868
# 19   24862   18777
# 20   19648   13460
# 21    8944    7951
# 22   13298    6591
# 23   48414   41330
# 24   17957   13154
# 25   21615   16574
# 26   26213   17852
# 27   17058   12075
# 28    3584    3085
# 29   16296   12658
# 30   26926   21905
# 31   20638   15888
# 32   12560   10298
# 33   16434   15534
# 34   33291   28710
# 35   27893   24538
# 36    6256    5405
# 37    7936    6508
# 38   12143   10092
# 39    4869    4309
# 40   22584   19325
# 41    2723    2398
# 42   85737   68441
# 43   13270   11566
# 44   33310   29479
# 45   23972   18603
# ...

# %%
y = dataset.iloc[: , -1 ]

# %%
y
# Out:
# 0      5209
# 1      7085
# 2      9059
# 3      5571
# 4      3807
# 5      2078
# 6      4598
# 7       265
# 8     22991
# 9       347
# 10     6199
# 11      475
# 12     1058
# 13      339
# 14      549
# 15      813
# 16    10902
# 17     5980
# 18     7868
# 19    18777
# 20    13460
# 21     7951
# 22     6591
# 23    41330
# 24    13154
# 25    16574
# 26    17852
# 27    12075
# 28     3085
# 29    12658
# 30    21905
# 31    15888
# 32    10298
# 33    15534
# 34    28710
# 35    24538
# 36     5405
# 37     6508
# 38    10092
# 39     4309
# 40    19325
# 41     2398
# 42    68441
# 43    11566
# 44    29479
# 45    18603
# 46     3160
# 47    16336
# 48     8675
# 49    21209
# 50    17254
# 51    14712
# 52    16908
# 53    13891
# 54    94268
# Name: billed, dtype: int64

# %%
X = dataset.iloc[: , 0:1]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X ,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict(24862)
# Out:
# array([20053.04242495])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X , y)
