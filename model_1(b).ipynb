# %%
import pandas as pd
dataset  =  pd.read_csv('model_1(b).csv')

# %%
dataset.shape
# Out:
# (33, 7)

# %%
y = dataset.iloc[: , 0]

# %%
y
# Out:
# 0     123.7
# 1     134.2
# 2     148.5
# 3     155.8
# 4     143.6
# 5     136.9
# 6     136.3
# 7     152.3
# 8     160.9
# 9     154.6
# 10    155.5
# 11    158.9
# 12    167.2
# 13    165.8
# 14    171.2
# 15    177.7
# 16    174.2
# 17    169.9
# 18    171.3
# 19    188.5
# 20    192.1
# 21    183.1
# 22    198.5
# 23    192.5
# 24    182.2
# 25    171.3
# 26    177.3
# 27    197.2
# 28    187.4
# 29    184.0
# 30    181.7
# 31    168.9
# 32    184.7
# Name: Energy, dtype: float64

# %%
X = dataset.iloc[: ,1:7]

# %%
X
# Out:
#     TMIN.W  TMAX.W  TMIN.S  TMAX.S  TMIN.I  TMAX.I
# 0   -6.313   4.007  15.521  27.188   4.854  17.167
# 1   -6.194   3.799  14.264  26.507   5.278  17.778
# 2   -4.993   4.153  15.931  29.896   5.049  16.257
# 3   -5.201   4.361  15.160  27.875   5.313  16.535
# 4   -7.569   2.542  14.708  27.132   7.333  18.944
# 5   -4.382   5.104  15.854  28.153   5.736  17.049
# 6   -3.389   6.014  16.083  28.493   5.035  18.069
# 7   -6.396   4.160  15.444  29.854   3.917  16.965
# 8   -6.326   3.319  15.313  26.681   4.313  16.257
# 9   -2.132   7.903  15.306  26.826   5.153  16.986
# 10  -3.556   5.438  15.792  28.743   6.819  17.701
# 11  -3.097   5.778  13.785  25.597   4.840  15.917
# 12  -5.174   3.375  15.646  26.458   4.618  16.083
# 13  -5.736   3.861  14.917  27.361   5.347  18.111
# 14  -5.576   4.694  16.139  28.354   4.208  15.896
# 15  -5.958   3.590  15.069  26.813   4.090  15.014
# 16  -4.271   4.625  14.993  26.458   3.403  14.861
# 17  -1.340   7.208  16.215  28.090   6.667  18.451
# 18  -4.868   5.222  15.271  28.646   5.993  18.833
# 19  -5.896   4.743  14.931  26.653   5.653  17.410
# 20  -4.090   5.049  15.007  26.993   6.833  19.403
# 21  -3.563   6.194  16.819  29.271   5.063  15.806
# 22  -5.903   3.813  14.826  26.590   5.646  17.646
# 23  -5.111   4.799  14.986  26.646   7.257  18.354
# 24  -4.701   4.215  16.847  28.882   5.528  17.944
# 25  -2.285   7.563  15.632  26.882   5.646  17.347
# 26  -4.604   4.569  15.736  29.069   6.188  18.660
# 27  -5.924   4.035  15.396  27.799   4.465  16.618
# 28  -5.604   4.583  15.000  26.097   5.556  16.521
# 29  -6.222   2.361  16.646  29.000   5.785  19.424
# 30  -4.299   4.757  16.326  27.924   6.368  17.799
# 31  -0.924   9.132  15.243  28.917   5.271  17.847
# 32  -5.542   3.493  15.382  27.174   5.299  16.688

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=10)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train ,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a=model.predict(X_test)

# %%
model.predict(X_test)
# Out:
# array([184.42672387, 168.59172562, 175.82075654, 183.5158782 ,
#        173.33659323, 164.79733733, 164.28547545, 180.45313094,
#        178.01689131, 159.1316897 , 163.3861047 , 175.42992787,
#        161.83939778, 170.64098185])

# %%
y_test
# Out:
# 21    183.1
# 7     152.3
# 5     136.9
# 2     148.5
# 3     155.8
# 22    198.5
# 13    165.8
# 24    182.2
# 12    167.2
# 1     134.2
# 20    192.1
# 14    171.2
# 19    188.5
# 6     136.3
# Name: Energy, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,a)
