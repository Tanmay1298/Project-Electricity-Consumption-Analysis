# %%
# pip3 install pandas

import pandas  as pd

# %%
dataset = pd.read_csv('model_3.csv')

# %%
dataset
# Out:
#     Billed Amount (Rs crore)  Collected Amount (Rs crore)
# 0                       2049                         1840
# 1                       3289                         3123
# 2                       2867                         2435
# 3                       2862                         2714
# 4                       2067                         1809
# 5                        986                          841
# 6                       2573                         2334
# 7                        130                          120
# 8                      14932                        15179
# 9                       3619                         3314
# 10                       544                          461
# 11                       198                          188
# 12                       105                           35
# 13                       496                          490
# 14                      8820                         8738
# ...

# %%
dataset['Billed Amount (Rs crore)']
# Out:
# 0      2049
# 1      3289
# 2      2867
# 3      2862
# 4      2067
# 5       986
# 6      2573
# 7       130
# 8     14932
# 9      3619
# 10      544
# 11      198
# 12      105
# 13      496
# 14     8820
# 15     4734
# 16     6581
# 17    11522
# 18     7768
# 19     4351
# 20     2012
# 21    17502
# 22     8302
# 23     9950
# 24    11460
# 25     5710
# 26     2102
# 27     5904
# 28    11781
# 29     5909
# 30     4667
# 31     7381
# 32    11906
# 33    12532
# 34     1734
# 35     3501
# 36     2445
# 37     1832
# 38    10873
# 39     1112
# 40    41444
# 41     3635
# 42    15720
# 43     9210
# 44     1235
# 45    10825
# 46     5089
# 47    11431
# 48     8199
# 49     5926
# 50     6333
# 51     6206
# 52    41548
# Name: Billed Amount (Rs crore), dtype: int64

# %%
y = dataset.iloc[: , 1]

# %%
x  = dataset.iloc[: , 0:1 ]

# %%
# pip3 install sklearn
import sklearn

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.fit(x , y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a=model.predict(x)
model.predict(x)
# Out:
# array([ 1969.86479226,  3159.12744895,  2754.39451256,  2749.59909863,
#         1987.12828244,   950.35978899,  2472.42417299,   129.38492275,
#        14325.72834562,  3475.62476888,   526.44519684,   194.60255231,
#          105.40785306,   480.40922304,  8463.81434747,  4545.00207712,
#         6316.42798591, 11055.25603971,  7454.85925486,  4177.67336944,
#         1934.37872912, 16790.57110989,  7967.00946347,  9547.57789752,
#        10995.79290688,  5481.06687787,  2020.69618001,  5667.12893867,
#        11303.65848172,  5671.92435261,  4480.74353034,  7083.69421604,
#        11423.54383017, 12023.92965525,  1667.75371415,  3362.45299994,
#         2349.66157617,  1761.74382734, 10432.81131053,  1071.20422023,
#        39752.93121191,  3490.97009348, 15081.48558229,  8837.85663466,
#         1189.17140311, 10386.77533672,  4885.47646673, 10967.97950604,
#         7868.22393634,  5688.22876   ,  6078.57545458,  5956.77194054,
#        39852.67582183])

# %%
y
# Out:
# 0      1840
# 1      3123
# 2      2435
# 3      2714
# 4      1809
# 5       841
# 6      2334
# 7       120
# 8     15179
# 9      3314
# 10      461
# 11      188
# 12       35
# 13      490
# 14     8738
# 15     4705
# 16     6562
# 17    10643
# 18     7367
# 19     4259
# 20     1674
# 21    16964
# 22     8430
# 23    10005
# 24    11261
# 25     3859
# 26     2061
# 27     5248
# 28    10747
# 29     5016
# 30     4995
# 31     7297
# 32    11455
# 33    12483
# 34     1766
# 35     3490
# 36     2464
# 37     1825
# 38    10656
# 39      985
# 40    41333
# 41     3533
# 42    15325
# 43     8701
# 44     1249
# 45    10726
# 46     5150
# 47    11441
# 48     8234
# 49     5272
# 50     6038
# 51     5931
# 52    37597
# Name: Collected Amount (Rs crore), dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(y,x)
